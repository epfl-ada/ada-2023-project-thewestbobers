# %%
PATH_HEADER = "MovieSummaries/"
CHARACTER = "character.metadata.tsv"
MOVIE = "movie.metadata.tsv"
PLOT_SUMMARIES = "plot_summaries.txt"
TVTROPES = "tvtropes.clusters.txt"

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# # Data Wrangling

# %%
column_names = [
    "WikipediaID",
    "FreebaseID",
]
summaries = pd.read_csv(PATH_HEADER + PLOT_SUMMARIES, names=column_names, header=None, delimiter="\t")
# Adjust 'delimiter' according to your file's format
display(summaries)
# Out:
#        WikipediaID                                         FreebaseID
# 0         23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1         31186339  The nation of Panem consists of a wealthy Capi...
# 2         20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3          2231378  The Lemon Drop Kid , a New York City swindler,...
# 4           595909  Seventh-day Adventist Church pastor Michael Ch...
# ...            ...                                                ...
# 42298     34808485  The story is about Reema , a young Muslim scho...
# 42299      1096473  In 1928 Hollywood, director Leo Andreyev  look...
# 42300     35102018  American Luthier focuses on Randy Parsons’ tra...
# 42301      8628195  Abdur Rehman Khan , a middle-aged dry fruit se...
# 42302      6040782  1940 - Operation Dynamo has just taken place. ...
#
# [42303 rows x 2 columns]

# %%
file_path = PATH_HEADER + TVTROPES 
parsed_data = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        category, json_str = line.split('\t', 1)
        json_data = json.loads(json_str)   
        json_data['category'] = category  # Add the category to the dictionary
        parsed_data.append(json_data)   # Append the dictionary to the list of parsed data

# Create a DataFrame from the list of dictionaries
tvtropes = pd.DataFrame(parsed_data)

# Now df holds your data, and you can manipulate it as needed

# %%
display(tvtropes)
# Out:
#                                   char                                  movie  \
# 0            Professor Philip Brainard                                Flubber
# 1                   Professor Keenbean                            Richie Rich
# 2                   Dr. Reinhardt Lane                             The Shadow
# 3                   Dr. Harold Medford                                  Them!
# 4                       Daniel Jackson                               Stargate
# ..                                 ...                                    ...
# 496                        Morgan Earp                              Tombstone
# 497                      Colorado Ryan                              Rio Bravo
# 498                         Tom Sawyer  The League of Extraordinary Gentlemen
# 499  William H. 'Billy the Kid' Bonney                          Young Guns II
# 500                               Jake                              Silverado
#
#              id            actor                 category
# 0     /m/0jy9q0   Robin Williams  absent_minded_professor
# 1    /m/02vchl3  Michael McShane  absent_minded_professor
# 2     /m/0k6fkc     Ian McKellen  absent_minded_professor
# 3     /m/0k6_br     Edmund Gwenn  absent_minded_professor
# 4     /m/0k3rhh     James Spader  absent_minded_professor
# ..          ...              ...                      ...
# 496   /m/0k776f      Bill Paxton                young_gun
# 497   /m/0k2kqg     Ricky Nelson                young_gun
# 498   /m/0k5nsh       Shane West                young_gun
# 499  /m/03lrjk0   Emilio Estevez                young_gun
# 500   /m/0k39jj    Kevin Costner                young_gun
#
# [501 rows x 5 columns]

# %%
column_names = [
    "WikipediaID",
    "FreebaseID",
    "date",
    "Character Name",
    "Actor DOB",
    "Actor Gender",
    "Actor Height",
    "Actor Ethnicity",
    "Actor Name",
    "Actor Age at Movie Release",
    "Freebase Character Map",
    "what",
    "wut"
]
characters = pd.read_csv(PATH_HEADER + CHARACTER, delimiter='\t', header=None, names=column_names)

# %%
display(characters)
# Out:
#         WikipediaID  FreebaseID        date              Character Name  \
# 0            975900   /m/03vyhn  2001-08-24                    Akooshay
# 1            975900   /m/03vyhn  2001-08-24  Lieutenant Melanie Ballard
# 2            975900   /m/03vyhn  2001-08-24         Desolation Williams
# 3            975900   /m/03vyhn  2001-08-24          Sgt Jericho Butler
# 4            975900   /m/03vyhn  2001-08-24             Bashira Kincaid
# ...             ...         ...         ...                         ...
# 450664       913762   /m/03pcrp  1992-05-21                      Elensh
# 450665       913762   /m/03pcrp  1992-05-21                      Hibiki
# 450666     28308153  /m/0cp05t9        1957                         NaN
# 450667     28308153  /m/0cp05t9        1957                         NaN
# 450668     28308153  /m/0cp05t9        1957                         NaN
#
#          Actor DOB Actor Gender  Actor Height Actor Ethnicity  \
# 0       1958-08-26            F         1.620             NaN
# 1       1974-08-15            F         1.780      /m/044038p
# 2       1969-06-15            M         1.727         /m/0x67
# 3       1967-09-12            M         1.750             NaN
# 4       1977-09-25            F         1.650             NaN
# ...            ...          ...           ...             ...
# 450664     1970-05            F           NaN             NaN
# 450665  1965-04-12            M           NaN             NaN
# 450666  1941-11-18            M         1.730       /m/02w7gg
# 450667         NaN          NaN           NaN             NaN
# 450668         NaN          NaN           NaN             NaN
#
#                 Actor Name  Actor Age at Movie Release Freebase Character Map  \
# 0           Wanda De Jesus                        42.0             /m/0bgchxw
# 1       Natasha Henstridge                        27.0              /m/0jys3m
# 2                 Ice Cube                        32.0              /m/0jys3g
# 3            Jason Statham                        33.0             /m/02vchl6
# 4              Clea DuVall                        23.0             /m/02vbb3r
# ...                    ...                         ...                    ...
# 450664  Dorothy Elias-Fahn                         NaN             /m/0kr406c
# 450665       Jonathan Fahn                        27.0             /m/0kr405_
# 450666      David Hemmings                        15.0             /m/0g8ngmc
# 450667    Roberta Paterson                         NaN             /m/0g8ngmj
# 450668         John Rogers                         NaN             /m/0g8ngmw
#
#               what         wut
# 0       /m/0bgcj3x  /m/03wcfv7
# 1       /m/0bgchn4   /m/0346l4
# 2       /m/0bgchn_  /m/01vw26l
# 3       /m/0bgchnq   /m/034hyc
# 4       /m/0bgchp9   /m/01y9xg
# ...            ...         ...
# 450664  /m/0kr406h   /m/0b_vcv
# 450665  /m/0kr4090   /m/0bx7_j
# 450666         NaN   /m/022g44
# 450667         NaN  /m/0g8ngmm
# 450668         NaN  /m/0btz19d
#
# [450669 rows x 13 columns]

# %%
column_names = [
    "wikipediaID",
    "freebaseID",
    "name",
    "date",
    "revenue",
    "runtime",
    "languages",
    "countries",
    "genres"
]
movies = pd.read_csv(PATH_HEADER + MOVIE, sep='\t', names=column_names, header=None)
display(movies)
# Out:
#        wikipediaID  freebaseID  \
# 0           975900   /m/03vyhn
# 1          3196793   /m/08yl5d
# 2         28463795  /m/0crgdbh
# 3          9363483  /m/0285_cd
# 4           261236   /m/01mrr1
# ...            ...         ...
# 81736     35228177  /m/0j7hxnt
# 81737     34980460  /m/0g4pl34
# 81738      9971909  /m/02pygw1
# 81739       913762   /m/03pcrp
# 81740     12476867  /m/02w7zz8
#
#                                                     name        date  \
# 0                                         Ghosts of Mars  2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...  2000-02-16
# 2                                            Brun bitter        1988
# 3                                       White Of The Eye        1987
# 4                                      A Woman in Flames        1983
# ...                                                  ...         ...
# 81736                           Mermaids: The Body Found  2011-03-19
# 81737                                            Knuckle  2011-01-21
# 81738                                  Another Nice Mess  1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...  1992-05-21
# 81740                                            Spliced        2002
#
#           revenue  runtime                           languages  \
# 0      14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1             NaN     95.0  {"/m/02h40lc": "English Language"}
# 2             NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3             NaN    110.0  {"/m/02h40lc": "English Language"}
# 4             NaN    106.0   {"/m/04306rv": "German Language"}
# ...           ...      ...                                 ...
# 81736         NaN    120.0  {"/m/02h40lc": "English Language"}
# 81737         NaN     96.0  {"/m/02h40lc": "English Language"}
# 81738         NaN     66.0  {"/m/02h40lc": "English Language"}
# 81739         NaN    150.0   {"/m/03_9r": "Japanese Language"}
# 81740         NaN     86.0  {"/m/02h40lc": "English Language"}
#
#                                                countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                                                   genres
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2      {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3      {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                                {"/m/07s9rl0": "Drama"}
# ...                                                  ...
# 81736                            {"/m/07s9rl0": "Drama"}
# 81737  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 81738       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
# 81739  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 81740  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
# [81741 rows x 9 columns]

# %%
parse_json = lambda s: json.loads(s)

# %%
movies["genres"] = movies["genres"].apply(parse_json)

# %%
movies["genres_dict"] = movies["genres"].copy()

# %%
movies["genres"] = movies["genres"].apply(lambda d: list(d.values()) if isinstance(d, dict) else d)

# %%
movies["genres"]
# Out:
# 0        [Thriller, Science Fiction, Horror, Adventure,...
# 1         [Mystery, Biographical film, Drama, Crime Drama]
# 2                                   [Crime Fiction, Drama]
# 3        [Thriller, Erotic thriller, Psychological thri...
# 4                                                  [Drama]
#                                ...
# 81736                                              [Drama]
# 81737              [Biographical film, Drama, Documentary]
# 81738                                     [Satire, Comedy]
# 81739    [Science Fiction, Japanese Movies, Adventure, ...
# 81740                    [Thriller, Horror, Slasher, Teen]
# Name: genres, Length: 81741, dtype: object

# %% [markdown]
# movies["genres"]

# %%
# Initialize an empty Counter object to accumulate counts
from collections import Counter
total_counts = Counter()
# Iterate over each element in the Series and update the Counter with values
movies["genres"].apply(lambda x: total_counts.update(x))
print(total_counts['Drama'])
# Out:
# 34007

# %%
print(len(total_counts))
# Out:
# 363

# %% [markdown]
# Drama, Comedy, Romance Film, Action, Thriller, Short Film, Wolrd cinema, Crime Fiction, Indie, Documentatry, Horror, Advendture, Family Film, Adventure, Musical, Animation, Romantic drama, Mystery, Science Fiction, Fantasy, Japanese Movies, Chinese Movies, Biography, Parody, Suspense, Supernatural, filme noir, Anime, Granster film, Docudram, Superhero movie, Concert film, Monster Movie, Animal Picture, Heist, Mockumentary, Stop motion, Tragedy, Auto-racing, Boxing, Delinquency Film, Stoner film, samurai Cinema, Extrem sports, Escape film, Sword and sorcery films,Alien Film

# %%
print(total_counts)
# Out:
# Counter({'Drama': 34007, 'Comedy': 16349, 'Romance Film': 10234, 'Black-and-white': 9094, 'Action': 8798, 'Thriller': 8744, 'Short Film': 8141, 'World cinema': 7155, 'Crime Fiction': 6948, 'Indie': 6897, 'Documentary': 5630, 'Horror': 5280, 'Silent film': 5250, 'Adventure': 4963, 'Family Film': 4598, 'Action/Adventure': 4561, 'Comedy film': 4362, 'Musical': 4160, 'Animation': 3534, 'Romantic drama': 3372, 'Mystery': 3195, 'Science Fiction': 3052, 'Fantasy': 2820, 'Romantic comedy': 2680, 'War film': 2652, 'Japanese Movies': 2322, 'Western': 2226, 'Crime Thriller': 2122, 'Period piece': 1758, 'Comedy-drama': 1720, 'Film adaptation': 1531, 'Chinese Movies': 1525, 'Biography': 1392, 'Psychological thriller': 1331, 'Bollywood': 1321, 'Sports': 1206, 'Biographical film': 1198, 'LGBT': 1163, 'Music': 1088, 'Family Drama': 1043, 'Black comedy': 1025, 'Parody': 999, 'Television movie': 972, 'Martial Arts Film': 928, "Children's/Family": 926, 'Teen': 925, 'Coming of age': 910, 'History': 888, 'Political drama': 799, 'Slasher': 768, 'Suspense': 759, 'Cult': 759, 'Culture & Society': 751, 'Melodrama': 721, 'Satire': 704, 'Supernatural': 641, 'Biopic [feature]': 635, 'Film noir': 622, 'Slapstick': 617, 'Historical fiction': 606, 'Crime Drama': 563, 'Action Thrillers': 516, "Children's": 508, 'B-movie': 493, 'Costume drama': 485, 'Spy': 474, 'Art film': 464, 'Ensemble Film': 453, 'Anime': 445, 'Gangster Film': 428, 'Docudrama': 420, 'Political cinema': 415, 'Detective': 405, 'Creature Film': 387, 'Buddy film': 372, 'Gay Themed': 357, 'Filipino Movies': 346, 'Road movie': 343, 'Detective fiction': 340, 'Sex comedy': 323, 'Social issues': 320, 'Historical drama': 317, 'Pornographic movie': 317, 'Erotica': 316, 'Crime Comedy': 307, 'Superhero movie': 302, 'Concert film': 301, 'Screwball comedy': 299, 'Gay': 289, 'Disaster': 287, 'Gay Interest': 287, "Children's Fantasy": 280, 'Epic': 278, 'Zombie Film': 274, 'Comedy of manners': 273, 'Experimental film': 258, 'Family-Oriented Adventure': 244, 'Courtroom Drama': 242, 'Political thriller': 242, 'Horror Comedy': 241, 'Musical comedy': 235, 'Computer Animation': 227, 'Fantasy Comedy': 224, 'Adult': 223, 'Fantasy Adventure': 220, 'Domestic Comedy': 213, 'Propaganda film': 213, 'Erotic thriller': 209, 'Comedy of Errors': 207, 'Rockumentary': 193, 'Musical Drama': 192, 'Marriage Drama': 190, 'Avant-garde': 190, 'Monster movie': 189, 'Animal Picture': 183, 'Pre-Code': 180, 'Natural horror films': 175, 'Heist': 174, 'Mockumentary': 173, 'Stop motion': 173, 'Action Comedy': 169, 'Christian film': 160, 'Erotic Drama': 156, 'Surrealism': 156, 'Childhood Drama': 148, 'Adventure Comedy': 144, 'Sci-Fi Horror': 143, 'Spaghetti Western': 141, 'Social problem film': 136, 'Prison': 131, 'Swashbuckler films': 127, 'Sexploitation': 126, 'Wuxia': 125, 'Superhero': 125, 'Doomsday film': 122, 'Film': 122, 'Slice of life story': 122, 'Animated cartoon': 122, 'Monster': 118, 'Dance': 116, 'Alien Film': 113, 'Holiday Film': 111, 'Chase Movie': 110, 'Caper story': 109, 'Blaxploitation': 107, 'Americana': 107, 'Costume Adventure': 106, 'Historical Epic': 103, 'Political satire': 102, 'Combat Films': 101, 'Tragedy': 101, 'Feminist Film': 99, 'Workplace Comedy': 97, 'Dystopia': 95, 'Christmas movie': 93, 'Stand-up comedy': 93, 'Absurdism': 92, 'Comedy Thriller': 91, 'Remake': 89, 'New Hollywood': 88, 'Time travel': 88, 'Media Satire': 88, 'Law & Crime': 85, 'Film & Television History': 80, 'Whodunit': 80, 'Hip hop movies': 80, 'Medical fiction': 79, 'Jungle Film': 79, 'Auto racing': 78, 'Boxing': 77, 'Gender Issues': 76, 'Haunted House Film': 76, 'Gothic Film': 73, 'Gay pornography': 73, 'Religious Film': 73, 'Comedy Western': 72, 'Romantic fantasy': 72, 'Revisionist Western': 69, 'Punk rock': 68, 'Tamil cinema': 67, 'Softcore Porn': 66, 'Nature': 65, 'Fairy tale': 64, 'B-Western': 63, 'Costume Horror': 62, 'Tragicomedy': 61, 'Addiction Drama': 61, 'Neo-noir': 60, 'Juvenile Delinquency Film': 59, 'Gross-out film': 58, 'Gro ...

# %%
print(total_counts['Horror'])
# Out:
# 5280

# %%
most_common = []
for genre, count in total_counts.most_common(30):
    most_common.append(genre)

# %%
print(most_common)
# Out:
# ['Drama', 'Comedy', 'Romance Film', 'Black-and-white', 'Action', 'Thriller', 'Short Film', 'World cinema', 'Crime Fiction', 'Indie', 'Documentary', 'Horror', 'Silent film', 'Adventure', 'Family Film', 'Action/Adventure', 'Comedy film', 'Musical', 'Animation', 'Romantic drama', 'Mystery', 'Science Fiction', 'Fantasy', 'Romantic comedy', 'War film', 'Japanese Movies', 'Western', 'Crime Thriller', 'Period piece', 'Comedy-drama']

# %%
display(movies)
# Out:
#        wikipediaID  freebaseID  \
# 0           975900   /m/03vyhn
# 1          3196793   /m/08yl5d
# 2         28463795  /m/0crgdbh
# 3          9363483  /m/0285_cd
# 4           261236   /m/01mrr1
# ...            ...         ...
# 81736     35228177  /m/0j7hxnt
# 81737     34980460  /m/0g4pl34
# 81738      9971909  /m/02pygw1
# 81739       913762   /m/03pcrp
# 81740     12476867  /m/02w7zz8
#
#                                                     name        date  \
# 0                                         Ghosts of Mars  2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...  2000-02-16
# 2                                            Brun bitter        1988
# 3                                       White Of The Eye        1987
# 4                                      A Woman in Flames        1983
# ...                                                  ...         ...
# 81736                           Mermaids: The Body Found  2011-03-19
# 81737                                            Knuckle  2011-01-21
# 81738                                  Another Nice Mess  1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...  1992-05-21
# 81740                                            Spliced        2002
#
#           revenue  runtime                           languages  \
# 0      14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1             NaN     95.0  {"/m/02h40lc": "English Language"}
# 2             NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3             NaN    110.0  {"/m/02h40lc": "English Language"}
# 4             NaN    106.0   {"/m/04306rv": "German Language"}
# ...           ...      ...                                 ...
# 81736         NaN    120.0  {"/m/02h40lc": "English Language"}
# 81737         NaN     96.0  {"/m/02h40lc": "English Language"}
# 81738         NaN     66.0  {"/m/02h40lc": "English Language"}
# 81739         NaN    150.0   {"/m/03_9r": "Japanese Language"}
# 81740         NaN     86.0  {"/m/02h40lc": "English Language"}
#
#                                                countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                                                   genres  \
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 2                                 [Crime Fiction, Drama]
# 3      [Thriller, Erotic thriller, Psychological thri...
# 4                                                [Drama]
# ...                                                  ...
# 81736                                            [Drama]
# 81737            [Biographical film, Drama, Documentary]
# 81738                                   [Satire, Comedy]
# 81739  [Science Fiction, Japanese Movies, Adventure, ...
# 81740                  [Thriller, Horror, Slasher, Teen]
#
#                                              genres_dict
# 0      {'/m/01jfsb': 'Thriller', '/m/06n90': 'Science...
# 1      {'/m/02n4kr': 'Mystery', '/m/03bxz7': 'Biograp...
# 2      {'/m/0lsxr': 'Crime Fiction', '/m/07s9rl0': 'D...
# 3      {'/m/01jfsb': 'Thriller', '/m/0glj9q': 'Erotic...
# 4                                {'/m/07s9rl0': 'Drama'}
# ...                                                  ...
# 81736                            {'/m/07s9rl0': 'Drama'}
# 81737  {'/m/03bxz7': 'Biographical film', '/m/07s9rl0...
# 81738       {'/m/06nbt': 'Satire', '/m/01z4y': 'Comedy'}
# 81739  {'/m/06n90': 'Science Fiction', '/m/0gw5n2f': ...
# 81740  {'/m/01jfsb': 'Thriller', '/m/03npn': 'Horror'...
#
# [81741 rows x 10 columns]

# %%
print(movies)
# Out:
#        wikipediaID  freebaseID  \
# 0           975900   /m/03vyhn
# 1          3196793   /m/08yl5d
# 2         28463795  /m/0crgdbh
# 3          9363483  /m/0285_cd
# 4           261236   /m/01mrr1
# ...            ...         ...
# 81736     35228177  /m/0j7hxnt
# 81737     34980460  /m/0g4pl34
# 81738      9971909  /m/02pygw1
# 81739       913762   /m/03pcrp
# 81740     12476867  /m/02w7zz8
#
#                                                     name        date  \
# 0                                         Ghosts of Mars  2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...  2000-02-16
# 2                                            Brun bitter        1988
# 3                                       White Of The Eye        1987
# 4                                      A Woman in Flames        1983
# ...                                                  ...         ...
# 81736                           Mermaids: The Body Found  2011-03-19
# 81737                                            Knuckle  2011-01-21
# 81738                                  Another Nice Mess  1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...  1992-05-21
# 81740                                            Spliced        2002
#
#           revenue  runtime                           languages  \
# 0      14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1             NaN     95.0  {"/m/02h40lc": "English Language"}
# 2             NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3             NaN    110.0  {"/m/02h40lc": "English Language"}
# 4             NaN    106.0   {"/m/04306rv": "German Language"}
# ...           ...      ...                                 ...
# 81736         NaN    120.0  {"/m/02h40lc": "English Language"}
# 81737         NaN     96.0  {"/m/02h40lc": "English Language"}
# 81738         NaN     66.0  {"/m/02h40lc": "English Language"}
# 81739         NaN    150.0   {"/m/03_9r": "Japanese Language"}
# 81740         NaN     86.0  {"/m/02h40lc": "English Language"}
#
#                                                countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                                                   genres  \
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 2                                 [Crime Fiction, Drama]
# 3      [Thriller, Erotic thriller, Psychological thri...
# 4                                                [Drama]
# ...                                                  ...
# 81736                                            [Drama]
# 81737            [Biographical film, Drama, Documentary]
# 81738                                   [Satire, Comedy]
# 81739  [Science Fiction, Japanese Movies, Adventure, ...
# 81740                  [Thriller, Horror, Slasher, Teen]
#
#                                              genres_dict
# 0      {'/m/01jfsb': 'Thriller', '/m/06n90': 'Science...
# 1      {'/m/02n4kr': 'Mystery', '/m/03bxz7': 'Biograp...
# 2      {'/m/0lsxr': 'Crime Fiction', '/m/07s9rl0': 'D...
# 3      {'/m/01jfsb': 'Thriller', '/m/0glj9q': 'Erotic...
# 4                                {'/m/07s9rl0': 'Drama'}
# ...                                                  ...
# 81736                            {'/m/07s9rl0': 'Drama'}
# 81737  {'/m/03bxz7': 'Biographical film', '/m/07s9rl0...
# 81738       {'/m/06nbt': 'Satire', '/m/01z4y': 'Comedy'}
# 81739  {'/m/06n90': 'Science Fiction', '/m/0gw5n2f': ...
# 81740  {'/m/01jfsb': 'Thriller', '/m/03npn': 'Horror'...
#
# [81741 rows x 10 columns]

# %% [markdown]
# # Date conversion

# %%
dates_copy = movies['date'].copy()
movies['date'] = pd.to_datetime(movies['date'], errors='coerce')

# %%
# Attempt to convert the 'date' column to datetime objects
movies['date'] = pd.to_datetime(dates_copy.copy(), errors='coerce', format='%Y-%m-%d')

# For entries where the conversion failed (which should be the ones with only the year), convert using just the year
movies.loc[movies['date'].isna(), 'date'] = pd.to_datetime(dates_copy.copy()[movies['date'].isna()], errors='coerce', format='%Y')

# Extract the year from the datetime objects
movies['year'] = movies['date'].dt.year

# %%
print(movies['date'])
# Out:
# 0       2001-08-24
# 1       2000-02-16
# 2       1988-01-01
# 3       1987-01-01
# 4       1983-01-01
#            ...
# 81736   2011-03-19
# 81737   2011-01-21
# 81738   1972-09-22
# 81739   1992-05-21
# 81740   2002-01-01
# Name: date, Length: 81741, dtype: datetime64[ns]

# %% [markdown]
# # Trailblazers of Cinematic Genres
#
# ## first movie of each most popular genre
#
#
# The inaugural films of any genre typically forge a path for future narratives, setting the stage with innovative themes, styles, or storytelling techniques. These films often stand as quintessential "pivot movies"—landmarks that inspire and influence the evolution of their respective genres. Beowl(after the codew, we present a list of the pioneering films that represent the genesis of the thirty most celebrated genres in cinema history:

# %%
movies['date'] = pd.to_datetime(movies['date'], errors='coerce')

# List of 30 most common genres
most_common_genres = most_common

# Initialize an empty list to store the earliest movies for each genre
earliest_movies_list = []

for genre in most_common_genres:
    # Filter for movies that include the genre and are not missing a date
    genre_movies = movies[movies['genres'].apply(lambda genres: genre in genres) & movies['date'].notnull()]
    
    # Find the earliest movie for the genre
    if not genre_movies.empty:
        earliest_movie_idx = genre_movies['date'].idxmin()
        earliest_movie = genre_movies.loc[earliest_movie_idx, ['name', 'date', 'genres']]
        # Append the earliest movie details to the list
        earliest_movies_list.append(earliest_movie)

# Convert the list of Series to a DataFrame
earliest_movies_per_genre = pd.DataFrame(earliest_movies_list)

# Reset the index of the resulting DataFrame
earliest_movies_per_genre.reset_index(drop=True, inplace=True)

# Now 'earliest_movies_per_genre' contains the earliest movie for each of the 30 genres
# with only the 'name', 'date', and 'genres' columns
for i in range(len(most_common)):
    print(   most_common[i] + ": \n" + str(earliest_movies_per_genre[['name', 'date', 'genres']].iloc[i] ))
# Out:
# Drama:
# name      Divers At Work on the Wreck of The Maine
# date                           1898-01-01 00:00:00
# genres            [Short Film, Silent film, Drama]
# Name: 0, dtype: object
# Comedy:
# name                             L'Arroseur Arrosé
# date                           1895-01-01 00:00:00
# genres    [Short Film, Silent film, Indie, Comedy]
# Name: 1, dtype: object
# Romance Film:
# name                               The Kiss
# date                    1896-01-01 00:00:00
# genres    [Short Film, Romance Film, Indie]
# Name: 2, dtype: object
# Black-and-white:
# name                                  Roundhay Garden Scene
# date                                    1888-01-01 00:00:00
# genres    [Short Film, Silent film, Indie, Black-and-white]
# Name: 3, dtype: object
# Action:
# name      The Bandit's Waterloo
# date        1908-08-04 00:00:00
# genres     [Short Film, Action]
# Name: 4, dtype: object
# Thriller:
# name      The Drover's Sweetheart
# date          1911-01-01 00:00:00
# genres          [Thriller, Drama]
# Name: 5, dtype: object
# Short Film:
# name                                  Roundhay Garden Scene
# date                                    1888-01-01 00:00:00
# genres    [Short Film, Silent film, Indie, Black-and-white]
# Name: 6, dtype: object
# World cinema:
# name                                  The Student of Prague
# date                                    1913-08-22 00:00:00
# genres    [Silent film, Horror, Indie, World cinema, Fan...
# Name: 7, dtype: object
# Crime Fiction:
# name                                             Barbe-bleu
# date                                    1901-01-01 00:00:00
# genres    [Crime Fiction, Silent film, Horror, Indie, Bl...
# Name: 8, dtype: object
# Indie:
# name                                  Roundhay Garden Scene
# date                                    1888-01-01 00:00:00
# genres    [Short Film, Silent film, Indie, Black-and-white]
# Name: 9, dtype: object
# Documentary:
# name                                      Fred Ott's Sneeze
# date                                    1894-01-01 00:00:00
# genres    [Short Film, Silent film, Indie, Black-and-whi...
# Name: 10, dtype: object
# Horror:
# name                                    Le Manoir du diable
# date                                    1896-12-24 00:00:00
# genres    [Short Film, Silent film, Horror, Indie, Black...
# Name: 11, dtype: object
# Silent film:
# name                                  Roundhay Garden Scene
# date                                    1888-01-01 00:00:00
# genres    [Short Film, Silent film, Indie, Black-and-white]
# Name: 12, dtype: object
# Adventure:
# name                                 The Pillar of Fire
# date                                1899-01-01 00:00:00
# genres    [Short Film, Silent film, Fantasy, Adventure]
# Name: 13, dtype: object
# Family Film:
# name                                       La Fée aux Choux
# date                                    1896-01-01 00:00:00
# genres    [Silent film, Indie, Black-and-white, Short Fi...
# Name: 14, dtype: object
# Action/Adventure:
# name                                   Martyrs of the Alamo
# date                                    1915-11-21 00:00:00
# genres    [Silent film, Historical fiction, Black-and-wh...
# Name: 15, dtype: object
# Comedy film:
# name                            A Terrible Night
# date                         1896-01-01 00:00:00
# genres    [Short Film, Silent film, Comedy film]
# Name: 16, dtype: object
# Musical:
# name                                          Otello
# date                             1906-10-30 00:00:00
# genres    [Short Film, Romance Film, Drama, Musical]
# Name: 17, dtype: object
# Animation:
# name                                      Un bon bock
# date                              1892-10-28 00:00:00
# genres    [Short Film, Silent film, Indie, Animation]
# Name: 18, dtype: object
# Romantic drama:
# name                       Les Amours de la reine Élisabeth
# date                                    1912-07-12 00:00:00
# genres    [Silent film, Melodrama, Historical fiction, S...
# Name: 19, dtype: object
# Mystery:
# name                   On the Broad Stairway
# date                     1913-07-19 00:00:00
# genres    [Short Film, Mystery, Silent film]
# Name: 20, dtype: object
# Science Fiction:
# name                                     A Trip to the Moon
# date                                    1902-09-01 00:00:00
# genres    [Science Fiction, Indie, Silent film, Black-an...
# Name: 21, dtype: object
# Fantasy:
# name                                       La Fée aux Choux
# date                                    1896-01-01 00:00:00
# genres    [Silent film, Indie, Black-and-white, Short Fi...
# Name: 22, dtype: object
# Romantic comedy:
# name                                     Choosing a Husband
# date                                    1909-12-30 00:00:00
# genres    [Short Film, Romantic comedy, Silent film, Dra...
# Name: 23, dtype: object
# War film:
# name                    La Prise de Tournavos
# date                      1897-01-01 00:00:00
# genres    [Short Film, Silent film, War film]
# Name: 24, dtype: object
# Japanese Movies:
# name                             Kosuzume Toge
# date                       1923-11-13 00:00:00
# genres    [Short Film, Drama, Japanese Movies]
# Name: 25, dtype: object
# Western:
# name                                          Buffalo Dance
# date                                    1894-01-01 00:00:00
# genres    [Silent film, Indie, Black-and-white, Short Fi...
# Name: 26, dtype: object
# Crime Thriller:
# name                                             After Five
# date                                    1915-01-28 00:00:00
# genres    [Thriller, Crime Fiction, Silent film, Indie, ...
# Name: 27, dtype: object
# Period piece:
# name                             Abraham Lincoln's Clemency
# date                                    1910-01-01 00:00:00
# genres    [Silent film, Melodrama, Indie, Black-and-whit...
# Name: 28, dtype: object
# Comedy-drama:
# name                              A Blowout at Santa Banana
# date                                    1914-01-26 00:00:00
# genres    [Silent film, Indie, Comedy-drama, Black-and-w...
# Name: 29, dtype: object

# %% [markdown]
# # Trope Originators
#
# Enclosed is a curated selection of seminal films, each marking the inaugural appearance of a particular trope. These films are esteemed as pivotal within the cinematic world, as they present audiences with the archetype of a character type for the very first time, setting the stage for countless others to follow.

# %%
tvtropes["name"] = tvtropes["movie"]

tvtropes_with_dates = pd.merge(tvtropes, movies[["name","date"]], on='name', how='left')

# %%
# Exclude rows where 'date' is NaT (not a time) or missing
tvtropes_copy = tvtropes.copy() 
tvtropes_with_dates_copy = tvtropes_with_dates.copy()
tvtropes = tvtropes_with_dates
tvtropes = tvtropes.dropna(subset=['date'])

# Continue with the rest of the process as before
tvtropes_sorted = tvtropes.sort_values(by=['category', 'date'])
first_movies_per_category = tvtropes_sorted.drop_duplicates(subset='category', keep='first')
pd.set_option('display.max_rows', None)
display(first_movies_per_category[['category', 'name', 'date']])
pd.reset_option('display.max_rows')
# Out:
#                         category  \
# 2        absent_minded_professor
# 13      adventurer_archaeologist
# 14           arrogant_kungfu_guy
# 33             big_man_on_campus
# 42                 bounty_hunter
# 48              brainless_beauty
# 73                   broken_bird
# 85                bromantic_foil
# 91    bruiser_with_a_soft_center
# 94                         bully
# 115                 byronic_hero
# 122                     casanova
# 138                    chanteuse
# 142                      charmer
# 154                child_prodigy
# 156           classy_cat_burglar
# 159      consummate_professional
# 183  corrupt_corporate_executive
# 191                       coward
# 219            crazy_jealous_guy
# 239            crazy_survivalist
# 243              cultured_badass
# 256               dean_bitterman
# 262                    dirty_cop
# 269                         ditz
# 275                      doormat
# 281         drill_sargeant_nasty
# 285                  dumb_blonde
# 297                  dumb_muscle
# 304             eccentric_mentor
# 308             egomaniac_hunter
# 329                  evil_prince
# 336      fastest_gun_in_the_west
# 340            father_to_his_men
# 361                   final_girl
# 365             gadgeteer_genius
# 374              gentleman_thief
# 387               granola_person
# 398               grumpy_old_man
# 400         hardboiled_detective
# 414           heartbroken_badass
# 421            henpecked_husband
# 436          hitman_with_a_heart
# 447                    jerk_jock
# 461               junkie_prophet
# 464                        klutz
# 470            loser_protagonist
# 476               loveable_rogue
# 487             master_swordsman
# 521      morally_bankrupt_banker
# 525      officer_and_a_gentleman
# 535                      ophelia
# 536               playful_hacker
# 545                  prima_donna
# 557              psycho_for_hire
# 568         pupil_turned_to_evil
# 573               retired_outlaw
# 579                      revenge
# 587            romantic_runnerup
# 589                self_made_man
# 601                      slacker
# 607                       stoner
# 621                  storyteller
# 628                stupid_crooks
# 638                  surfer_dude
# 639                    the_chief
# 644                   the_editor
# 646                tranquil_fury
# 656                    trickster
# 661                  valley_girl
# 688                 warrior_poet
# 692                    young_gun
#
#                                              name       date
# 2                                      The Shadow 1940-01-05
# 13                                      The Mummy 1932-12-22
# 14                               Enter the Dragon 1973-07-26
# 33                              Can't Hardly Wait 1998-06-12
# 42                              The Bounty Hunter 1954-01-01
# 48                                    Fool's Gold 1919-05-26
# 73                            Alice in Wonderland 1915-01-19
# 85                                       Mallrats 1995-10-20
# 91                                  Casino Royale 1954-01-01
# 94                              A Christmas Story 1983-11-18
# 115                                      Iron Man 1931-04-30
# 122                                      Casanova 1918-01-01
# 138                              Some Like It Hot 1939-01-01
# 142                                 Casino Royale 1954-01-01
# 154                                   Real Genius 1985-08-07
# 156                              To Catch a Thief 1936-01-01
# 159                           The Bourne Identity 1988-01-01
# 183                              Edge of Darkness 1943-01-01
# 191                                     The Mummy 1932-12-22
# 219                                      Scarface 1932-01-01
# 239                                           Red 2002-01-01
# 243                                 Casino Royale 1954-01-01
# 256                           The Nutty Professor 1963-01-01
# 262                                 Touch of Evil 1958-04-23
# 269                                        Arthur 1981-07-17
# 275                            Back to the Future 1985-07-03
# 281                                       Stripes 1981-06-26
# 285                               Dinner at Eight 1933-08-29
# 297               It's a Mad, Mad, Mad, Mad World 1963-11-07
# 304  Star Wars Episode V: The Empire Strikes Back 1980-05-21
# 308                          Beauty and the Beast 1983-11-11
# 329                                        Sheena 1984-08-17
# 336                                  3:10 to Yuma 1957-08-07
# 340                      She Wore a Yellow Ribbon 1949-01-01
# 361                                     Halloween 1978-10-25
# 365                                      Iron Man 1931-04-30
# 374                              To Catch a Thief 1936-01-01
# 387                                   Hocus Pocus 1993-07-16
# 398                                       Network 1976-11-14
# 400                            The Maltese Falcon 1931-05-28
# 414                        The Outlaw Josey Wales 1976-06-30
# 421                               What's Up, Doc? 1950-01-01
# 436                                        Wanted 1967-03-22
# 447                          Beauty and the Beast 1983-11-11
# 461                               Minority Report 2002-06-17
# 464                        Little Shop of Horrors 1986-12-19
# 470                                 High Fidelity 2000-03-17
# 476                           The Thief of Bagdad 1924-01-01
# 487  Star Wars Episode V: The Empire Strikes Back 1980-05-21
# 521                         It's a Wonderful Life 1946-12-20
# 525                                         Glory 1956-01-01
# 535                   The Cabinet of Dr. Caligari 1920-02-26
# 536                                          Tron 1982-07-09
# 545                                 All About Eve 1950-01-01
# 557                          Arsenic and Old Lace 1944-09-23
# 568                                    The Hunted 1995-02-24
# 573            Butch Cassidy and the Sundance Kid 1969-09-23
# 579                        For a Few Dollars More 1965-12-18
# 587                                 Reality Bites 1994-02-18
# 589                        The Philadelphia Story 1940-12-23
# 601                                       Stripes 1981-06-26
# 607                  Fast Times at Ridgemont High 1982-08-13
# 621                                     Peter Pan 1924-01-01
# 628                                         Fargo 1996-03-08
# 638                                Apocalypse Now 1979-05-10
# 639                              The Pink Panther 1963-12-19
# 644                               His Girl Friday 1940-01-11
# 646                                      The Crow 1919-09-15
# 656  Star Wars Episode V: The Empire Strikes Back 1980-05-21
# 661                                   Valley Girl 1983-04-29
# 688                            Lawrence of Arabia 1962-12-10
# 692                                     Rio Bravo 1959-03-18

# %% [markdown]
# # Hype Generator
#
# To effectively identify the 'hype generator', it's essential to define 'hype' precisely. We have opted to measure hype as the annual percentage change in the production of various movie genres. This approach accounts for the evolving ease of movie production and the resultant increase in the overall number of films produced each year. By focusing on yearly percentage changes, we can effectively neutralize the impact of the growing volume of movie production, ensuring our analysis remains robust and accurate.
#
# Next, we aim to identify the specific movie that sparked this hype. To do this, we will analyze the movies within the relevant genres and pinpoint the one with the highest revenue over the preceding six years. This approach helps us determine which film played a pivotal role in generating the observed increase in genre popularity.

# %%
"""
calculates the percentage of each genre per year
"""

df = movies.copy()
# Explode the 'genres' list into separate rows
df_exploded = df.explode('genres')

# Group by year and genre, then count occurrences
genre_counts = df_exploded.groupby(['year', 'genres']).size()

# Convert the Series into a DataFrame
genre_counts_df = genre_counts.reset_index(name='count')

# Calculate the total count for each year
total_counts = genre_counts_df.groupby('year')['count'].transform('sum')

# Calculate the percentage
genre_counts_df['percentage'] = (genre_counts_df['count'] / total_counts) * 100

# %%
"""
Plot the stacked genre %  by year (1990-2013) of the top 20 genres.
"""

years_to_plot = [1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000, 2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013]  # You can add more years to this list
data_to_plot = genre_counts_df[genre_counts_df['year'].isin(years_to_plot)]


data_sorted = data_filtered.sort_values(['year', 'genres'])

top_genres = genre_counts_df['genres'].value_counts().head(20).index


data_filtered = data_to_plot[data_to_plot['genres'].isin(top_genres)]


data_sorted = data_filtered.sort_values(['year', 'genres'])

unique_genres = data_sorted['genres'].unique()
unique_years = data_sorted['year'].unique()


genre_colors = {genre: plt.cm.tab20(i / len(unique_genres)) for i, genre in enumerate(unique_genres)}

fig, ax = plt.subplots(figsize=(18, 8))


for year in unique_years: # Create a stacked bar chart
    bottom = np.zeros(len(unique_years))  # Initialize the bottom array for this year
    year_data = data_sorted[data_sorted['year'] == year]

    for genre in unique_genres:
        genre_data = year_data[year_data['genres'] == genre]
        if not genre_data.empty:
            percentage = genre_data['percentage'].values[0]
            ax.bar(str(year), percentage, bottom=bottom, color=genre_colors[genre], label=genre)
            bottom += percentage


ax.set_ylim(0, 100)


ax.set_xlabel('Year')
ax.set_ylabel('Percentage')
ax.set_title('Stacked Genre Percentages by Year for Top 20 Genres')

ax.legend(genre_colors.keys(), title="Genres", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()

plt.show()

# %%
"""
Plot the stacked genre %  by year by year (1990-2013) of between the top 20 and 40 genres.
"""
years_to_plot = [1990,1991,1992,1992,1993,1994,1995,1996,1997,1998,1999,2000, 2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013]  # You can add more years to this list
data_to_plot = genre_counts_df[genre_counts_df['year'].isin(years_to_plot)]

data_sorted = data_filtered.sort_values(['year', 'genres'])


genre_value_counts = genre_counts_df['genres'].value_counts()

# Select the genres ranked from 20th to 40th
top_genres = genre_value_counts.iloc[19:40].index  


data_filtered = data_to_plot[data_to_plot['genres'].isin(top_genres)]


data_sorted = data_filtered.sort_values(['year', 'genres'])


unique_genres = data_sorted['genres'].unique()
unique_years = data_sorted['year'].unique()


genre_colors = {genre: plt.cm.tab20(i / len(unique_genres)) for i, genre in enumerate(unique_genres)}

fig, ax = plt.subplots(figsize=(18, 8))
genres = top_genres.to_list()
# Create a stacked bar chart
for year in unique_years:
    bottom = np.zeros(len(unique_years))  # Initialize the bottom array for this year
    year_data = data_sorted[data_sorted['year'] == year]

    for genre in unique_genres:
        genre_data = year_data[year_data['genres'] == genre]
        if not genre_data.empty:
            percentage = genre_data['percentage'].values[0]
            ax.bar(str(year), percentage, bottom=bottom, color=genre_colors[genre], label=genre)
            bottom += percentage


ax.set_ylim(0, 22)


ax.set_xlabel('Year')
ax.set_ylabel('Percentage')
ax.set_title('Stacked Genre Percentages by Year for Top 20-40 Genres')


ax.legend(genre_colors.keys(), title="Genres", bbox_to_anchor=(1.05, 1), loc='upper left')


plt.tight_layout()

plt.show()

# %%
"""
Plot the stacked genre % by year by year (1990-2013) of between the top 40 and 60 genres.
"""
years_to_plot = [1990,1991,1992,1992,1993,1994,1995,1996,1997,1998,1999,2000, 2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013]  # You can add more years to this list
data_to_plot = genre_counts_df[genre_counts_df['year'].isin(years_to_plot)]


data_sorted = data_filtered.sort_values(['year', 'genres'])


genre_value_counts = genre_counts_df['genres'].value_counts()


top_genres = genre_value_counts.iloc[39:60].index


data_filtered = data_to_plot[data_to_plot['genres'].isin(top_genres)]


data_sorted = data_filtered.sort_values(['year', 'genres'])

# Extract the unique genres and years
unique_genres = data_sorted['genres'].unique()
unique_years = data_sorted['year'].unique()

genre_colors = {genre: plt.cm.tab20(i / len(unique_genres)) for i, genre in enumerate(unique_genres)}


fig, ax = plt.subplots(figsize=(18, 8))
genres = top_genres.to_list()

for year in unique_years: # Create a stacked bar chart
    bottom = np.zeros(len(unique_years))  # Initialize the bottom array for this year
    year_data = data_sorted[data_sorted['year'] == year]

    for genre in unique_genres:
        genre_data = year_data[year_data['genres'] == genre]
        if not genre_data.empty:
            percentage = genre_data['percentage'].values[0]
            ax.bar(str(year), percentage, bottom=bottom, color=genre_colors[genre], label=genre)
            bottom += percentage


ax.set_ylim(0, 10)


ax.set_xlabel('Year')
ax.set_ylabel('Percentage')
ax.set_title('Stacked Genre Percentages by Year for Top 40-60 Genres')


ax.legend(genre_colors.keys(), title="Genres", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()

plt.show()
